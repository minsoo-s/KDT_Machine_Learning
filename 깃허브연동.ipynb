# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git clone https://minsoo-s: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@github.com/minsoo-s/MachineLearning.git
# Out:
# Cloning into 'MachineLearning'...
# ...

# %%
cd MachineLearning/
# Out:
# /content/drive/MyDrive/Colab Notebooks/MachineLearning

# %%
# !git config --global user.email 'alstn6754@outlook.com'
# !git config --global user.name 'minsoo-s'
